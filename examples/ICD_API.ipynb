# %%
import httpx
import os

# %%
# --- ICD API Config ---
TOKEN_URL = "https://icdaccessmanagement.who.int/connect/token"
ICD_SEARCH_URL = "https://id.who.int/icd/release/11/2022-02/mms/search"

CLIENT_ID = os.environ.get("ICD_CLIENT_ID", "")
CLIENT_SECRET = os.environ.get("ICD_CLIENT_SECRET", "")
SCOPE = "icdapi_access"
GRANT_TYPE = "client_credentials"


def get_token() -> str:
    """
    Authenticate with the WHO ICD API and return an access token.
    """
    payload = {
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET,
        "scope": SCOPE,
        "grant_type": GRANT_TYPE,
    }

    with httpx.Client(verify=True) as client:
        response = client.post(TOKEN_URL, data=payload)
        response.raise_for_status()
        token = response.json().get("access_token")
        return token


get_token()
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..fq5yUf68NrFYp4ziHdtda8DXq90vEcvhU_VlIiVnEYRFtn5IdVF9z1GIe3kAzIdnPwIxc66_WFqxOJ0TUf7923MbxjEo-Q75jrqT2RsUA2w9_RPi_rJOKNuwIx3f2HCrL1jEn3_TadiEmjtO8HLEWvJ37IeLIic5ttpx2VQKHu7w4jBznN0cx32gskF7LyLJSXQBn4kB0YKWaFfDs5YV8mcvOAjvsxykPryw_xvLBKGWGDURaJrSs6m_eEjDC9e9krWB0ONtEH-yJlejJ6uodcCBoXsrNzdcJP5K5IBt590oej_eBi3lZGhMnd-1AVTwUNvdBeTtc5LrDYtV_-sGPA'

# %%
def lookup_icd11(term: str, token: str) -> dict:
    """
    Search for ICD-11 codes using a search term and return the results.
    """
    headers = {
        "Authorization": f"Bearer {token}",
        "Accept": "application/json",
        "Accept-Language": "en",
        "API-Version": "v2",
    }

    params = {
        "q": term,
        "useFlexisearch": "true",
    }

    with httpx.Client(verify=False) as client:
        response = client.get(ICD_SEARCH_URL, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()

    return data


data = lookup_icd11("diabetes", get_token())

# %%
data.get("destinationEntities", [])
# Out:
# [{'id': 'http://id.who.int/icd/release/11/2022-02/mms/1697306310',
#   'title': "<em class='found'>Diabetes</em> mellitus, type unspecified",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1697306310',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> NOS",
#     'score': 1,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "controlled <em class='found'>diabetes</em>",
#     'score': 0.6372643850780286,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "controlled <em class='found'>diabetic</em>",
#     'score': 0.6372643850780286,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> mellitus NOS",
#     'score': 0.6102474889459157,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "severe <em class='found'>diabetes</em> mellitus",
#     'score': 0.3649775698312872,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "controlled <em class='found'>diabetes</em> mellitus",
#     'score': 0.24751187402394445,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "DM - [<em class='found'>diabetes</em> mellitus] NOS",
#     'score': 0.07224416545920309,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>Diabetes</em> mellitus, type unspecified without complications",
#     'score': -0.08907619811196031,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "sudden-onset <em class='found'>diabetes</em> mellitus",
#     'score': -0.08928800453794931,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0},
#    {'propertyId': 'FullySpecifiedName',
#     'label': "<em class='found'>Diabetes</em> without mention of type of <em class='found'>diabetes</em> mellitus",
#     'score': -0.17107845858209964,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1697306310',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A14',
#   'score': 1,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1320503631',
#   'title': "<em class='found'>Diabetes</em> mellitus arising in pregnancy",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1320503631',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> of pregnancy",
#     'score': 0.7239533351654975,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1320503631',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "gestational <em class='found'>diabetes</em>",
#     'score': 0.634058747097998,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1320503631',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Gestational <em class='found'>diabetes</em> mellitus NOS",
#     'score': 0.24430623604391372,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1320503631',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "maternal gestational <em class='found'>diabetes</em> mellitus",
#     'score': -0.07401487249797509,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1320503631',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "GDM - [gestational <em class='found'>diabetes</em> mellitus]",
#     'score': -0.47685300288942467,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1320503631',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "gestational <em class='found'>diabetes</em> complicating pregnancy, childbirth, or the puerperium",
#     'score': -1.390481286762334,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1320503631',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '18',
#   'theCode': 'JA63.2',
#   'score': 0.7239533351654975,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/388963453',
#   'title': "<em class='found'>Diabetes</em> mellitus due to drug or chemical",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/388963453',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "chemical <em class='found'>diabetes</em>",
#     'score': 0.6328994288932901,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/388963453',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A13.4',
#   'score': 0.6328994288932901,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/108919913',
#   'title': 'Disorders of phosphorus metabolism or phosphatases',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/108919913',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "Phosphate <em class='found'>diabetes</em>",
#     'score': 0.593100830260744,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/496350246',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5C64.3',
#   'score': 0.593100830260744,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/119724091',
#   'title': "Type 2 <em class='found'>diabetes</em> mellitus",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/119724091',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "type 2 <em class='found'>diabetes</em>",
#     'score': 0.5905295676150176,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>Diabetic</em> type 2",
#     'score': 0.5905295676150176,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "type II <em class='found'>diabetes</em>",
#     'score': 0.45660530214942935,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "stable <em class='found'>diabetes</em>",
#     'score': 0.4448939959393547,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "adult onset <em class='found'>diabetes</em>",
#     'score': 0.4051791586438529,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "nonketotic <em class='found'>diabetes</em>",
#     'score': 0.4039234504074365,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "maturity onset <em class='found'>diabetes</em>",
#     'score': 0.40097408391008144,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "insulin resistant <em class='found'>diabetes</em>",
#     'score': 0.24784900341848762,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1255683285',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> mellitus Type 2",
#     'score': 0.2007770565609334,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Type II <em class='found'>diabetes</em> mellitus",
#     'score': 0.06685279109534509,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "maturity-onset <em class='found'>diabetes</em> mellitus",
#     'score': 0.011221572855997277,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "noninsulin dependent <em class='found'>diabetes</em>",
#     'score': -0.010937800810320098,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Title',
#     'label': "Insulin resistant <em class='found'>diabetes</em> mellitus",
#     'score': -0.14190350763559653,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1255683285',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "insulin requiring type 2 <em class='found'>diabetes</em>",
#     'score': -0.15442679137184492,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> due to insulin secretory defect",
#     'score': -0.2220660640497895,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "senile <em class='found'>diabetes</em>",
#     'score': -0.22298344291197747,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Title',
#     'label': "Ketosis-resistant <em class='found'>diabetes</em> mellitus",
#     'score': -0.3767276344908798,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/618467158',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "non-insulin dependent <em class='found'>diabetes</em> mellitus",
#     'score': -0.40069031186440424,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "non-insulin-dependent <em class='found'>diabetes</em> of the young",
#     'score': -0.45187181509373536,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> mellitus due to insulin secretory defect",
#     'score': -0.6118185751038736,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "T2DM - [Type 2 <em class='found'>diabetes</em> mellitus]",
#     'score': -0.6731281231085956,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "non-insulin-dependent <em class='found'>diabetes</em> mellitus without complications",
#     'score': -0.9032337358357028,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "NIDDM - [non insulin dependent <em class='found'>diabetes</em> mellitus]",
#     'score': -1.0755301723274548,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/119724091',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A11',
#   'score': 0.5905295676150176,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/186534168/other',
#   'title': 'Other specified syndromic genetic deafness',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/186534168/other',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "Mitochondrial <em class='found'>diabetes</em>",
#     'score': 0.5862450886308539,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/2133824111',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Maternally inherited <em class='found'>diabetes</em> and deafness",
#     'score': -0.8457817561732367,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/2133824111',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Atherosclerosis - deafness - <em class='found'>diabetes</em> - epilepsy - nephropathy",
#     'score': -4.249227128495463,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1437964451',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '20',
#   'theCode': 'LD2H.Y',
#   'score': 0.5862450886308539,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1651053999',
#   'title': "Type 1 <em class='found'>diabetes</em> mellitus",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1651053999',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "Type 1 <em class='found'>diabetes</em>",
#     'score': 0.5779287318419587,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1651053999',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Juvenile onset <em class='found'>diabetes</em> mellitus",
#     'score': -0.018619382797933234,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1727622794',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Idiopathic Type 1 <em class='found'>diabetes</em> mellitus",
#     'score': -0.1533499805504089,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/702044482',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Fulminant type 1 <em class='found'>diabetes</em> mellitus",
#     'score': -0.31090865508803983,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1237768242',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Immune-related Type 1 <em class='found'>diabetes</em> mellitus",
#     'score': -0.3774066422804074,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1727622794',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "Immune-mediated Type 1 <em class='found'>diabetes</em> mellitus",
#     'score': -0.510601153494588,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1727622794',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "juvenile <em class='found'>diabetes</em> mellitus without compications",
#     'score': -0.6361876530708827,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1651053999',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "T1DM - [Type 1 <em class='found'>diabetes</em> mellitus]",
#     'score': -0.6857289588816545,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1651053999',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "IDDM - [insulin dependent <em class='found'>diabetes</em> mellitus]",
#     'score': -0.7695490214802566,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1651053999',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "slowly progressive insulin-dependent <em class='found'>diabetes</em> mellitus",
#     'score': -0.8817586198753146,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1918279014',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "juvenile-onset <em class='found'>diabetes</em> mellitus without compications",
#     'score': -0.924602063291757,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1651053999',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Idiopathic insulin-dependent <em class='found'>diabetes</em> mellitus without complications",
#     'score': -0.9658738857886171,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1651053999',
#     'propertyValueType': 0},
#    {'propertyId': 'Title',
#     'label': "Latent autoimmune <em class='found'>diabetes</em> in adults",
#     'score': -1.106855399987148,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1918279014',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "juvenile-onset-type <em class='found'>diabetes</em> mellitus without compications",
#     'score': -1.1213823263783345,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1651053999',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "ketosis-prone <em class='found'>diabetes</em> mellitus without compications",
#     'score': -1.517810235618233,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1651053999',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "SPIDDM - [Slowly progressive insulin-dependent <em class='found'>diabetes</em> mellitus]",
#     'score': -1.5565984803383652,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1918279014',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "LADA - [Latent autoimmune <em class='found'>diabetes</em> in adults]",
#     'score': -1.7816952604501983,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1918279014',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A10',
#   'score': 0.5779287318419587,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/74527684',
#   'title': "<em class='found'>Diabetic</em> foot ulcer",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/74527684',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': True,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "<em class='found'>Diabetic</em> foot",
#     'score': 0.5588003754209693,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/74527684',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Neuropathic ulceration of foot due to <em class='found'>diabetes</em>",
#     'score': -0.64515801179062,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/74527684',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '11',
#   'theCode': 'BD54',
#   'score': 0.5588003754209693,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1156295616',
#   'title': "Uncontrolled or unstable <em class='found'>diabetes</em> mellitus",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1156295616',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "uncontrolled <em class='found'>diabetes</em>",
#     'score': 0.5061248836769491,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1156295616',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "labile <em class='found'>diabetes</em>",
#     'score': 0.48148986830965307,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/23809728',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "brittle <em class='found'>diabetes</em>",
#     'score': 0.47010658393946786,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1156295616',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "inadequate control of <em class='found'>diabetes</em>",
#     'score': 0.20572472275843973,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1156295616',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "poorly controlled <em class='found'>diabetes</em>",
#     'score': 0.16507363185796967,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1156295616',
#     'propertyValueType': 0},
#    {'propertyId': 'Title',
#     'label': "Brittle <em class='found'>diabetes</em> mellitus",
#     'score': 0.0803540728853837,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/23809728',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "brittle DM - [<em class='found'>diabetes</em> mellitus]",
#     'score': -0.45764925060132905,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/23809728',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "brittle type 1 <em class='found'>diabetes</em> mellites",
#     'score': -0.6923482021603705,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/23809728',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "brittle IDDM - [insulin dependent <em class='found'>diabetes</em> mellitus]",
#     'score': -1.2994424375407887,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/23809728',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A24',
#   'score': 0.5061248836769491,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1009553897',
#   'title': "Central <em class='found'>diabetes</em> insipidus",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1009553897',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> insipidus",
#     'score': 0.5038594213814416,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1009553897',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "familial <em class='found'>diabetes</em> insipidus",
#     'score': 0.21356617552808935,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1009553897',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> mellitus insipidus",
#     'score': 0.11410691032735738,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1009553897',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "DI - [<em class='found'>diabetes</em> insipidus]",
#     'score': 0.09496074323616932,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1009553897',
#     'propertyValueType': 0},
#    {'propertyId': 'Title',
#     'label': "Cranial <em class='found'>diabetes</em> insipidus",
#     'score': 0.042927500422057875,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1409762098',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "neurogenic <em class='found'>diabetes</em> insipidus",
#     'score': 0.011634382415799354,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1009553897',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "primary central <em class='found'>diabetes</em> insipidus",
#     'score': -0.05180768872117345,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1009553897',
#     'propertyValueType': 0},
#    {'propertyId': 'Title',
#     'label': "Acquired central <em class='found'>diabetes</em> insipidus",
#     'score': -0.07750960768414568,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1677009817',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Traumatic central <em class='found'>diabetes</em> insipidus",
#     'score': -0.10879703076291489,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1994772612',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Acquired central <em class='found'>diabetes</em> due to Infiltrative disease",
#     'score': -0.11274537705075911,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/587449571',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Neurohypophyseal <em class='found'>diabetes</em> insipidus",
#     'score': -0.1799036393572609,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/97299603',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Non-acquired central <em class='found'>diabetes</em> insipidus",
#     'score': -0.35639565906951487,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1627007407',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Idiopathic acquired central <em class='found'>diabetes</em> insipidus",
#     'score': -0.419035809022429,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1037418324',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> insipidus secondary to vasopressin deficiency",
#     'score': -1.073334772783386,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1009553897',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>Diabetes</em> insipidus, <em class='found'>diabetes</em> mellitus, optic atrophy, and deafness",
#     'score': -1.7308044261446167,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/151381747',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "DIDMOAD - [<em class='found'>Diabetes</em> insipidus, <em class='found'>diabetes</em> mellitus, optic atrophy, and deafness] syndrome",
#     'score': -2.615679491420965,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/151381747',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A61.5',
#   'score': 0.5038594213814416,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1010481205',
#   'title': "Syndrome of infant of a <em class='found'>diabetic</em> mother, type 1 or 2, nongestational, insulin dependent",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1010481205',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "maternal <em class='found'>diabetes</em> syndrome",
#     'score': 0.5030515558477945,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> embryopathy",
#     'score': 0.4651543381450309,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/778367655',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "infant of <em class='found'>diabetic</em> mother",
#     'score': 0.2374842669875158,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "syndrome of infant of <em class='found'>diabetic</em> mother",
#     'score': 0.05885693137719906,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "infant of a <em class='found'>diabetic</em> mother syndrome",
#     'score': -0.07089273522714189,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "hypoglycaemia in infant of <em class='found'>diabetic</em> mother",
#     'score': -1.0954017768141604,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "neonatal hypoglycaemia in maternal <em class='found'>diabetes</em>",
#     'score': -1.2076002201263918,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "maternal <em class='found'>diabetes</em> mellitus affecting fetus or newborn",
#     'score': -1.347844277820802,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Hypertrophic cardiomyopathy in infant of <em class='found'>diabetic</em> mother",
#     'score': -1.9210235562838534,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Syndrome of infant of a <em class='found'>diabetic</em> mother, type I or II, nongestational, insulin dependent",
#     'score': -2.2626529808427636,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Fetus or newborn affected by pre-existing maternal <em class='found'>diabetes</em> mellitus",
#     'score': -2.586246978407456,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "maternal <em class='found'>diabetes</em> mellitus affecting fetus or newborn with hypoglycaemia",
#     'score': -2.680730321622478,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "pre-existing maternal <em class='found'>diabetes</em> mellitus affecting fetus or newborn with hypoglycaemia",
#     'score': -3.9191330222091323,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1010481205',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '19',
#   'theCode': 'KB60.1',
#   'score': 0.5030515558477945,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1583355636/unspecified',
#   'title': 'Intermediate hyperglycaemia, unspecified',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1583355636/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "latent <em class='found'>diabetes</em>",
#     'score': 0.4876390070723604,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1583355636',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': 'prediabetes',
#     'score': 0.14195930242995347,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1583355636',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '05',
#   'theCode': '5A40.Z',
#   'score': 0.4876390070723604,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/412389819/unspecified',
#   'title': 'Chronic kidney disease, stage unspecified',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/412389819/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> kidney disease",
#     'score': 0.46709952871526145,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/615062102',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "DKD - [<em class='found'>diabetic</em> kidney disease]",
#     'score': -0.25405971021807694,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/615062102',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> nephropathy",
#     'score': -0.40484527867106235,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1905915973',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetic</em> nephrosclerosis",
#     'score': -0.8985735376539667,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1905915973',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '16',
#   'theCode': 'GB61.Z',
#   'score': 0.46709952871526145,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1217915084/unspecified',
#   'title': "Neonatal <em class='found'>diabetes</em> mellitus, unspecified",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1217915084/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "neonatal <em class='found'>diabetes</em>",
#     'score': 0.4436069322171734,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1217915084',
#     'propertyValueType': 0},
#    {'propertyId': 'TitleOfOtherEntity',
#     'label': "Neonatal <em class='found'>diabetes</em> mellitus",
#     'score': 0.053854421163089236,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1217915084',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> mellitus syndrome in newborn infant",
#     'score': -0.9507793385759167,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1217915084',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '19',
#   'theCode': 'KB60.2Z',
#   'score': 0.4436069322171734,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/396058882/other',
#   'title': 'Other specified disorders of iron metabolism',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/396058882/other',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "bronze <em class='found'>diabetes</em>",
#     'score': 0.4064454379224375,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1517378334',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetic</em> hemochromatosis",
#     'score': -0.5484122196517872,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1517378334',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5C64.1Y',
#   'score': 0.4064454379224375,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1736778',
#   'title': 'Insulin-resistance syndromes',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1736778',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "Lipoatrophic <em class='found'>diabetes</em>",
#     'score': 0.3464407265618275,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1628738474',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A44',
#   'score': 0.3464407265618275,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/923657942',
#   'title': "<em class='found'>Diabetic</em> glomerular changes",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/923657942',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetic</em> glomerulopathy",
#     'score': 0.340071648804256,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/923657942',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Glomerular disorders in <em class='found'>diabetes</em> mellitus",
#     'score': -0.17066140259865162,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/923657942',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '21',
#   'theCode': 'MF83',
#   'score': 0.340071648804256,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/169360210/unspecified',
#   'title': "<em class='found'>Diabetes</em> mellitus in pregnancy, unspecified",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/169360210/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'TitleOfOtherEntity',
#     'label': "<em class='found'>Diabetes</em> mellitus in pregnancy",
#     'score': 0.3342008241114134,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/169360210',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> mellitus complicating pregnancy, childbirth, or the puerperium",
#     'score': -1.4142925449144161,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/169360210',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '18',
#   'theCode': 'JA63.Z',
#   'score': 0.3342008241114134,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/913893315',
#   'title': "<em class='found'>Diabetic</em> skin lesions",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/913893315',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': True,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> dermopathy",
#     'score': 0.32516013953694956,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/62999288',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> bullae",
#     'score': -0.614009970460138,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/877816714',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '14',
#   'theCode': 'EB90.0',
#   'score': 0.3310222664172921,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/895101139/other',
#   'title': 'Other specified disorders of cutaneous connective tissue',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/895101139/other',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> cheiroarthropathy",
#     'score': 0.3162369392612976,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/283404213',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> scleroedema",
#     'score': -0.7121517655822514,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1525650994',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>Diabetic</em> scleredema",
#     'score': -0.7121517655822514,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1525650994',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>Diabetic</em> sclerodactyly",
#     'score': -0.8042761475927998,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/283404213',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': True,
#   'isResidualUnspecified': False,
#   'chapter': '14',
#   'theCode': 'EE7Y',
#   'score': 0.3162369392612976,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/381961554',
#   'title': "<em class='found'>Diabetes</em> mellitus, other specified type",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/381961554',
#   'isLeaf': False,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'FullySpecifiedName',
#     'label': "Other specified <em class='found'>Diabetes</em> mellitus, not Type 1 and not Type 2",
#     'score': -0.4018584624438281,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/381961554',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A13',
#   'score': 0.24704670190740552,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/632323575',
#   'title': 'Anterior ischemic optic neuropathy',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/632323575',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> papillopathy",
#     'score': 0.23252138259637367,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1393672297',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '09',
#   'theCode': '9C40.40',
#   'score': 0.23252138259637367,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1417669099',
#   'title': "Nephrogenic <em class='found'>diabetes</em> insipidus",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1417669099',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "<em class='found'>diabetes</em> tenuifluus",
#     'score': 0.23252138259637367,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1417669099',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "familial nephrogenic <em class='found'>diabetes</em>",
#     'score': 0.16122247365534997,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1417669099',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "renal <em class='found'>diabetes</em> insipidus",
#     'score': 0.12819403816122898,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1417669099',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "congenital nephrogenic <em class='found'>diabetes</em> insipidus",
#     'score': -0.2526278604792545,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1417669099',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "primary nephrogenic <em class='found'>diabetes</em> insipidus",
#     'score': -0.29307224522772696,
#     'important': False,
# ...
#     'label': "hypoglycaemia in infant of mother with gestational <em class='found'>diabetes</em>",
#     'score': -1.4613430297161627,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1500607905',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "hypoglycaemia in neonate of mother with gestational <em class='found'>diabetes</em>",
#     'score': -1.6563176504834738,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1500607905',
#     'propertyValueType': 0},
#    {'propertyId': 'Synonym',
#     'label': "Fetus or newborn with hypoglycaemia affected by maternal gestational <em class='found'>diabetes</em>",
#     'score': -2.656919063470396,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1500607905',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '19',
#   'theCode': 'KB60.0',
#   'score': -0.12845698591448637,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1770509481',
#   'title': 'Secondary brachial plexus lesion due to certain specified disorders',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1770509481',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> brachial plexus lesion",
#     'score': -0.1462633234451382,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1655054999',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '08',
#   'theCode': '8B95',
#   'score': -0.1462633234451382,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/700864997',
#   'title': 'Neovascular secondary angle closure glaucoma',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/700864997',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> glaucoma",
#     'score': -0.14919338058889303,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/604005609',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "<em class='found'>Diabetes</em> mellitus with glaucoma",
#     'score': -0.5389458916429771,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/604005609',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Secondary angle closure glaucoma by neovascular membrane due to <em class='found'>diabetic</em> retinopathy",
#     'score': -4.299115246753697,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/943647258',
#     'propertyValueType': 1},
#    {'propertyId': 'Synonym',
#     'label': "Secondary angle closure glaucoma by neovascular membrane, without pupillary block, due to <em class='found'>diabetic</em> retinopathy",
#     'score': -5.409170224268473,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/943647258',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '09',
#   'theCode': '9C61.32',
#   'score': -0.14919338058889303,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/340836242',
#   'title': "<em class='found'>Diabetic</em> cataract",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/340836242',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': True,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '09',
#   'theCode': '9B10.21',
#   'score': -0.15402431827327948,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/367815473',
#   'title': "<em class='found'>Diabetic</em> coma",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/367815473',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '05',
#   'theCode': '5A23',
#   'score': -0.19155540480954164,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1006882070/unspecified',
#   'title': "<em class='found'>Diabetic</em> retinopathy, unspecified",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1006882070/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': True,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'TitleOfOtherEntity',
#     'label': "<em class='found'>Diabetic</em> retinopathy",
#     'score': -0.24076166179112787,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1006882070',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '09',
#   'theCode': '9B71.0Z',
#   'score': -0.24076166179112787,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/97556145/unspecified',
#   'title': 'Male erectile dysfunction, unspecified',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/97556145/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "Erectile dysfunction due to <em class='found'>diabetes</em> mellitus",
#     'score': -0.24352273940363417,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1004674961',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '17',
#   'theCode': 'HA01.1Z',
#   'score': -0.24352273940363417,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/514403112/unspecified',
#   'title': 'Cystic fibrosis, unspecified',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/514403112/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "unspecified cystic fibrosis-associated <em class='found'>diabetes</em> mellitus",
#     'score': -0.2504028324821405,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1870098646',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '12',
#   'theCode': 'CA25.Z',
#   'score': -0.2504028324821405,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/2144077558/unspecified',
#   'title': "<em class='found'>Diabetic</em> acidosis, unspecified",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/2144077558/unspecified',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': True,
#   'matchingPVs': [{'propertyId': 'TitleOfOtherEntity',
#     'label': "<em class='found'>Diabetic</em> acidosis",
#     'score': -0.25861670977575607,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/2144077558',
#     'propertyValueType': 0}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': True,
#   'chapter': '05',
#   'theCode': '5A22.Z',
#   'score': -0.25861670977575607,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/655608138',
#   'title': 'Necrobiosis lipoidica',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/655608138',
#   'isLeaf': True,
#   'postcoordinationAvailability': 0,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> necrobiosis lipoidica",
#     'score': -0.2702769340023291,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1029082545',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '14',
#   'theCode': 'EE80.1',
#   'score': -0.2702769340023291,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1129679469',
#   'title': "Autonomic neuropathy due to <em class='found'>diabetes</em> mellitus",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1129679469',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': True,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': "<em class='found'>Diabetic</em> autonomic neuropathy",
#     'score': -0.29688741650638584,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1129679469',
#     'propertyValueType': 0},
#    {'propertyId': 'Title',
#     'label': "Generalised <em class='found'>diabetic</em> autonomic neuropathy",
#     'score': -0.5900741942499185,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/381537364',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Treatment associated <em class='found'>diabetic</em> autonomic neuropathy",
#     'score': -0.8490194194840798,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1574233531',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '08',
#   'theCode': '8D88.1',
#   'score': -0.29688741650638584,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1593715151',
#   'title': 'Intentional self-harm by and exposure to other and unspecified drug, medicament and biological substance',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1593715151',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': 'Intentional harmful effect of antidiabetic drugs',
#     'score': -0.32637930955045835,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/684109772',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '23',
#   'theCode': 'PC98',
#   'score': -0.32637930955045835,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/799356470',
#   'title': 'Unintentional exposure to or harmful effects of other or unspecified drug, medicament or biological substance',
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/799356470',
#   'isLeaf': True,
#   'postcoordinationAvailability': 1,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Synonym',
#     'label': 'Unintentional harmful effect of antidiabetic drugs',
#     'score': -0.37751342430357054,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1463814604',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '23',
#   'theCode': 'PB28',
#   'score': -0.37751342430357054,
#   'titleIsASearchResult': False,
#   'titleIsTopScore': False,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1116345240',
#   'title': "<em class='found'>Diabetic</em> macular oedema",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1116345240',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': False,
#   'hasMaternalChapterLink': False,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [{'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> macular oedema apparently present",
#     'score': -1.101516988713483,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/960326099',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "<em class='found'>Diabetic</em> macular oedema apparently absent",
#     'score': -1.1404773507080106,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/684055088',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Severe <em class='found'>diabetic</em> macular oedema, Retinal thickening or hard exudates involving the centre of the macula",
#     'score': -3.648330390395916,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/407032800',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Moderate <em class='found'>diabetic</em> macular oedema, Retinal thickening or hard exudates approaching the centre of the macula but not involving the centre",
#     'score': -4.6966024315017485,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/301589723',
#     'propertyValueType': 1},
#    {'propertyId': 'Title',
#     'label': "Mild <em class='found'>diabetic</em> macular oedema, Some retinal thickening or hard exudates in posterior pole but distant from the centre of the macula",
#     'score': -5.664422564604513,
#     'important': False,
#     'foundationUri': 'http://id.who.int/icd/entity/1001632806',
#     'propertyValueType': 1}],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '09',
#   'theCode': '9B71.02',
#   'score': -0.4073052804304776,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'descendants': []},
#  {'id': 'http://id.who.int/icd/release/11/2022-02/mms/1224666577',
#   'title': "<em class='found'>Diabetic</em> lumbosacral plexopathy",
#   'stemId': 'http://id.who.int/icd/release/11/2022-02/mms/1224666577',
#   'isLeaf': True,
#   'postcoordinationAvailability': 2,
#   'hasCodingNote': True,
#   'hasMaternalChapterLink': True,
#   'hasPerinatalChapterLink': False,
#   'matchingPVs': [],
#   'propertiesTruncated': False,
#   'isResidualOther': False,
#   'isResidualUnspecified': False,
#   'chapter': '08',
#   'theCode': '8B92.2',
#   'score': -0.4149216891702645,
#   'titleIsASearchResult': True,
#   'titleIsTopScore': True,
#   'entityType': 0,
#   'important': False,
#   'descendants': []}]
